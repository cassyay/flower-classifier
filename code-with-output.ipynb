# %% [markdown]
# <a href="https://colab.research.google.com/github/cassyay/flower-classifier/blob/master/code-with-output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
import torchvision 
from torchvision import transforms, datasets
import torch 
#from workspace_utils import active_session
from torch.utils.data import DataLoader
import torchvision.models as models
model = models.alexnet(pretrained=True)
from collections import OrderedDict
from torch import nn, optim
import numpy as np
from PIL import Image
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
# !unzip flower_data.zip
data_dir = 'flower_data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets

training_transform = transforms.Compose([
        transforms.RandomRotation(90),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
validation_transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
testing_transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])


# TODO: Load the datasets with ImageFolder
training_data = datasets.ImageFolder(train_dir, transform=training_transform)
validation_data = datasets.ImageFolder(valid_dir, transform=validation_transform)
testing_data = datasets.ImageFolder(test_dir, transform = testing_transform)

# TODO: Using the image datasets and the trainforms, define the dataloaders
training_loader = torch.utils.data.DataLoader(training_data, batch_size=32, shuffle=True) 
validation_loader = torch.utils.data.DataLoader(validation_data, batch_size = 32)
testing_loader = torch.utils.data.DataLoader(testing_data, batch_size = 32)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
for param in model.parameters():
    param.requires_grad = False

input_size = 9216
hidden_sizes = [1024, 256]
output_size = 102


model.classifier = nn.Sequential(OrderedDict([
                      ('fc1', nn.Linear(input_size, hidden_sizes[0])),
                      ('relu1', nn.ReLU()),
                      ('dropout1', nn.Dropout(p=0.1)),
                      ('fc2', nn.Linear(hidden_sizes[0], hidden_sizes[1])),
                      ('relu2', nn.ReLU()),
                      ('dropout2', nn.Dropout(p=0.1)),
                      ('fc3', nn.Linear(hidden_sizes[1], output_size)),
                      ('output', nn.LogSoftmax(dim=1))]))

classifier = model.classifier
criterion = nn.NLLLoss()
optimizer = optim.SGD(model.classifier.parameters(), lr=0.01)
model.cuda()
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=9216, out_features=1024, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (fc2): Linear(in_features=1024, out_features=256, bias=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (fc3): Linear(in_features=256, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
epochs = 7
steps = 0
print_every = 5
train_losses, validation_losses = [], []
    
    
for e in range(epochs):
    running_loss = 0
    for images, labels in training_loader:
        steps += 1
        images, labels = images.to('cuda'), labels.to('cuda')
        
        optimizer.zero_grad()
                
        log_ps = model.forward(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
            

        if steps % print_every == 0:
            validation_loss = 0
            accuracy = 0
            model.eval()
                
            with torch.no_grad():
                for images, labels in validation_loader:
                    images, labels = images.to('cuda'), labels.to('cuda')
                    log_ps = model.forward(images)
                    batch_loss = criterion(log_ps, labels) 
                    validation_loss += batch_loss.item()   
                    ps = torch.exp(log_ps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor))
       
    
            train_losses.append(running_loss/len(training_loader)), 
            validation_losses.append(validation_loss/len(validation_loader))  

            print("Epoch: {}/{}..".format(e+1, epochs),
            "Training loss: {:.3f}..".format(running_loss/print_every),
            "Validation loss: {:.3f}..".format(validation_loss/len(validation_loader)),
            "Test accuracy: {:.3f}".format(accuracy/len(validation_loader)))
            running_loss = 0
            model.train()
# Out:
# Epoch: 1/7.. Training loss: 4.633.. Validation loss: 4.584.. Test accuracy: 0.028
# Epoch: 1/7.. Training loss: 4.600.. Validation loss: 4.542.. Test accuracy: 0.049
# Epoch: 1/7.. Training loss: 4.595.. Validation loss: 4.502.. Test accuracy: 0.082
# Epoch: 1/7.. Training loss: 4.548.. Validation loss: 4.460.. Test accuracy: 0.129
# Epoch: 1/7.. Training loss: 4.492.. Validation loss: 4.418.. Test accuracy: 0.079
# Epoch: 1/7.. Training loss: 4.479.. Validation loss: 4.374.. Test accuracy: 0.089
# Epoch: 1/7.. Training loss: 4.370.. Validation loss: 4.343.. Test accuracy: 0.079
# Epoch: 1/7.. Training loss: 4.474.. Validation loss: 4.284.. Test accuracy: 0.096
# Epoch: 1/7.. Training loss: 4.400.. Validation loss: 4.254.. Test accuracy: 0.099
# Epoch: 1/7.. Training loss: 4.432.. Validation loss: 4.199.. Test accuracy: 0.097
# Epoch: 1/7.. Training loss: 4.251.. Validation loss: 4.155.. Test accuracy: 0.096
# Epoch: 1/7.. Training loss: 4.308.. Validation loss: 4.080.. Test accuracy: 0.106
# Epoch: 1/7.. Training loss: 4.240.. Validation loss: 4.016.. Test accuracy: 0.103
# Epoch: 1/7.. Training loss: 4.223.. Validation loss: 3.963.. Test accuracy: 0.150
# Epoch: 1/7.. Training loss: 4.130.. Validation loss: 3.919.. Test accuracy: 0.156
# Epoch: 1/7.. Training loss: 4.029.. Validation loss: 3.859.. Test accuracy: 0.126
# Epoch: 1/7.. Training loss: 4.049.. Validation loss: 3.782.. Test accuracy: 0.171
# Epoch: 1/7.. Training loss: 4.042.. Validation loss: 3.747.. Test accuracy: 0.150
# Epoch: 1/7.. Training loss: 3.931.. Validation loss: 3.691.. Test accuracy: 0.208
# Epoch: 1/7.. Training loss: 3.813.. Validation loss: 3.680.. Test accuracy: 0.155
# Epoch: 1/7.. Training loss: 3.974.. Validation loss: 3.561.. Test accuracy: 0.198
# Epoch: 1/7.. Training loss: 3.824.. Validation loss: 3.518.. Test accuracy: 0.209
# Epoch: 1/7.. Training loss: 3.661.. Validation loss: 3.476.. Test accuracy: 0.168
# Epoch: 1/7.. Training loss: 3.744.. Validation loss: 3.466.. Test accuracy: 0.188
# Epoch: 1/7.. Training loss: 3.673.. Validation loss: 3.358.. Test accuracy: 0.209
# Epoch: 1/7.. Training loss: 3.641.. Validation loss: 3.258.. Test accuracy: 0.214
# Epoch: 1/7.. Training loss: 3.597.. Validation loss: 3.214.. Test accuracy: 0.202
# Epoch: 1/7.. Training loss: 3.562.. Validation loss: 3.148.. Test accuracy: 0.263
# Epoch: 1/7.. Training loss: 3.700.. Validation loss: 3.123.. Test accuracy: 0.304
# Epoch: 1/7.. Training loss: 3.437.. Validation loss: 3.052.. Test accuracy: 0.284
# Epoch: 1/7.. Training loss: 3.577.. Validation loss: 2.984.. Test accuracy: 0.320
# Epoch: 1/7.. Training loss: 3.481.. Validation loss: 2.948.. Test accuracy: 0.345
# Epoch: 1/7.. Training loss: 3.191.. Validation loss: 2.914.. Test accuracy: 0.298
# Epoch: 1/7.. Training loss: 3.319.. Validation loss: 2.857.. Test accuracy: 0.293
# Epoch: 1/7.. Training loss: 3.403.. Validation loss: 2.825.. Test accuracy: 0.338
# Epoch: 1/7.. Training loss: 3.243.. Validation loss: 2.737.. Test accuracy: 0.365
# Epoch: 1/7.. Training loss: 3.228.. Validation loss: 2.679.. Test accuracy: 0.395
# Epoch: 1/7.. Training loss: 3.048.. Validation loss: 2.619.. Test accuracy: 0.380
# Epoch: 1/7.. Training loss: 3.094.. Validation loss: 2.566.. Test accuracy: 0.389
# Epoch: 1/7.. Training loss: 3.097.. Validation loss: 2.584.. Test accuracy: 0.380
# Epoch: 1/7.. Training loss: 2.979.. Validation loss: 2.517.. Test accuracy: 0.415
# Epoch: 2/7.. Training loss: 2.867.. Validation loss: 2.454.. Test accuracy: 0.411
# Epoch: 2/7.. Training loss: 2.872.. Validation loss: 2.456.. Test accuracy: 0.413
# Epoch: 2/7.. Training loss: 2.809.. Validation loss: 2.492.. Test accuracy: 0.392
# Epoch: 2/7.. Training loss: 2.607.. Validation loss: 2.421.. Test accuracy: 0.378
# Epoch: 2/7.. Training loss: 2.809.. Validation loss: 2.318.. Test accuracy: 0.442
# Epoch: 2/7.. Training loss: 2.769.. Validation loss: 2.289.. Test accuracy: 0.404
# Epoch: 2/7.. Training loss: 2.858.. Validation loss: 2.278.. Test accuracy: 0.458
# Epoch: 2/7.. Training loss: 2.713.. Validation loss: 2.233.. Test accuracy: 0.448
# Epoch: 2/7.. Training loss: 2.899.. Validation loss: 2.182.. Test accuracy: 0.453
# Epoch: 2/7.. Training loss: 2.571.. Validation loss: 2.118.. Test accuracy: 0.478
# Epoch: 2/7.. Training loss: 2.822.. Validation loss: 2.053.. Test accuracy: 0.501
# Epoch: 2/7.. Training loss: 2.562.. Validation loss: 2.075.. Test accuracy: 0.447
# Epoch: 2/7.. Training loss: 2.724.. Validation loss: 2.062.. Test accuracy: 0.463
# Epoch: 2/7.. Training loss: 2.691.. Validation loss: 2.048.. Test accuracy: 0.478
# Epoch: 2/7.. Training loss: 2.630.. Validation loss: 1.954.. Test accuracy: 0.507
# Epoch: 2/7.. Training loss: 2.622.. Validation loss: 1.993.. Test accuracy: 0.478
# Epoch: 2/7.. Training loss: 2.373.. Validation loss: 1.898.. Test accuracy: 0.518
# Epoch: 2/7.. Training loss: 2.511.. Validation loss: 1.860.. Test accuracy: 0.531
# Epoch: 2/7.. Training loss: 2.507.. Validation loss: 1.803.. Test accuracy: 0.574
# Epoch: 2/7.. Training loss: 2.462.. Validation loss: 1.840.. Test accuracy: 0.529
# Epoch: 2/7.. Training loss: 2.095.. Validation loss: 1.886.. Test accuracy: 0.537
# Epoch: 2/7.. Training loss: 2.324.. Validation loss: 1.852.. Test accuracy: 0.533
# Epoch: 2/7.. Training loss: 2.425.. Validation loss: 1.895.. Test accuracy: 0.497
# Epoch: 2/7.. Training loss: 2.275.. Validation loss: 1.720.. Test accuracy: 0.561
# Epoch: 2/7.. Training loss: 2.337.. Validation loss: 1.697.. Test accuracy: 0.599
# Epoch: 2/7.. Training loss: 2.181.. Validation loss: 1.730.. Test accuracy: 0.537
# Epoch: 2/7.. Training loss: 2.233.. Validation loss: 1.700.. Test accuracy: 0.560
# Epoch: 2/7.. Training loss: 2.089.. Validation loss: 1.657.. Test accuracy: 0.575
# Epoch: 2/7.. Training loss: 2.472.. Validation loss: 1.648.. Test accuracy: 0.549
# Epoch: 2/7.. Training loss: 2.031.. Validation loss: 1.679.. Test accuracy: 0.541
# Epoch: 2/7.. Training loss: 2.088.. Validation loss: 1.616.. Test accuracy: 0.573
# Epoch: 2/7.. Training loss: 2.158.. Validation loss: 1.593.. Test accuracy: 0.583
# Epoch: 2/7.. Training loss: 2.127.. Validation loss: 1.613.. Test accuracy: 0.592
# Epoch: 2/7.. Training loss: 2.191.. Validation loss: 1.569.. Test accuracy: 0.600
# Epoch: 2/7.. Training loss: 2.410.. Validation loss: 1.534.. Test accuracy: 0.579
# Epoch: 2/7.. Training loss: 2.363.. Validation loss: 1.603.. Test accuracy: 0.581
# Epoch: 2/7.. Training loss: 1.910.. Validation loss: 1.497.. Test accuracy: 0.585
# Epoch: 2/7.. Training loss: 2.113.. Validation loss: 1.549.. Test accuracy: 0.561
# Epoch: 2/7.. Training loss: 2.082.. Validation loss: 1.485.. Test accuracy: 0.622
# Epoch: 2/7.. Training loss: 2.025.. Validation loss: 1.425.. Test accuracy: 0.630
# Epoch: 2/7.. Training loss: 1.821.. Validation loss: 1.379.. Test accuracy: 0.632
# Epoch: 3/7.. Training loss: 1.991.. Validation loss: 1.436.. Test accuracy: 0.598
# Epoch: 3/7.. Training loss: 1.964.. Validation loss: 1.441.. Test accuracy: 0.623
# Epoch: 3/7.. Training loss: 2.030.. Validation loss: 1.355.. Test accuracy: 0.670
# Epoch: 3/7.. Training loss: 1.779.. Validation loss: 1.398.. Test accuracy: 0.607
# Epoch: 3/7.. Training loss: 2.089.. Validation loss: 1.363.. Test accuracy: 0.645
# Epoch: 3/7.. Training loss: 1.912.. Validation loss: 1.346.. Test accuracy: 0.651
# Epoch: 3/7.. Training loss: 1.956.. Validation loss: 1.403.. Test accuracy: 0.609
# Epoch: 3/7.. Training loss: 1.696.. Validation loss: 1.390.. Test accuracy: 0.611
# Epoch: 3/7.. Training loss: 1.825.. Validation loss: 1.308.. Test accuracy: 0.640
# Epoch: 3/7.. Training loss: 1.987.. Validation loss: 1.357.. Test accuracy: 0.629
# Epoch: 3/7.. Training loss: 1.979.. Validation loss: 1.291.. Test accuracy: 0.662
# Epoch: 3/7.. Training loss: 1.780.. Validation loss: 1.301.. Test accuracy: 0.659
# Epoch: 3/7.. Training loss: 1.979.. Validation loss: 1.249.. Test accuracy: 0.681
# Epoch: 3/7.. Training loss: 1.836.. Validation loss: 1.265.. Test accuracy: 0.654
# Epoch: 3/7.. Training loss: 1.663.. Validation loss: 1.296.. Test accuracy: 0.672
# Epoch: 3/7.. Training loss: 1.764.. Validation loss: 1.264.. Test accuracy: 0.661
# Epoch: 3/7.. Training loss: 1.851.. Validation loss: 1.241.. Test accuracy: 0.670
# Epoch: 3/7.. Training loss: 1.723.. Validation loss: 1.236.. Test accuracy: 0.669
# Epoch: 3/7.. Training loss: 1.630.. Validation loss: 1.311.. Test accuracy: 0.655
# Epoch: 3/7.. Training loss: 1.731.. Validation loss: 1.301.. Test accuracy: 0.655
# Epoch: 3/7.. Training loss: 1.859.. Validation loss: 1.242.. Test accuracy: 0.671
# Epoch: 3/7.. Training loss: 1.782.. Validation loss: 1.189.. Test accuracy: 0.673
# Epoch: 3/7.. Training loss: 1.921.. Validation loss: 1.186.. Test accuracy: 0.685
# Epoch: 3/7.. Training loss: 1.873.. Validation loss: 1.169.. Test accuracy: 0.687
# Epoch: 3/7.. Training loss: 1.707.. Validation loss: 1.145.. Test accuracy: 0.686
# Epoch: 3/7.. Training loss: 1.696.. Validation loss: 1.159.. Test accuracy: 0.695
# Epoch: 3/7.. Training loss: 1.675.. Validation loss: 1.198.. Test accuracy: 0.682
# Epoch: 3/7.. Training loss: 1.523.. Validation loss: 1.154.. Test accuracy: 0.688
# Epoch: 3/7.. Training loss: 1.911.. Validation loss: 1.129.. Test accuracy: 0.683
# Epoch: 3/7.. Training loss: 1.386.. Validation loss: 1.106.. Test accuracy: 0.696
# Epoch: 3/7.. Training loss: 1.758.. Validation loss: 1.043.. Test accuracy: 0.730
# Epoch: 3/7.. Training loss: 1.622.. Validation loss: 1.063.. Test accuracy: 0.713
# Epoch: 3/7.. Training loss: 1.651.. Validation loss: 1.090.. Test accuracy: 0.709
# Epoch: 3/7.. Training loss: 1.754.. Validation loss: 1.147.. Test accuracy: 0.685
# Epoch: 3/7.. Training loss: 1.807.. Validation loss: 1.057.. Test accuracy: 0.722
# Epoch: 3/7.. Training loss: 1.724.. Validation loss: 1.039.. Test accuracy: 0.728
# Epoch: 3/7.. Training loss: 1.602.. Validation loss: 1.056.. Test accuracy: 0.703
# Epoch: 3/7.. Training loss: 1.451.. Validation loss: 1.005.. Test accuracy: 0.738
# Epoch: 3/7.. Training loss: 1.826.. Validation loss: 1.144.. Test accuracy: 0.679
# Epoch: 3/7.. Training loss: 1.648.. Validation loss: 1.159.. Test accuracy: 0.662
# Epoch: 3/7.. Training loss: 1.784.. Validation loss: 1.120.. Test accuracy: 0.695
# Epoch: 4/7.. Training loss: 1.634.. Validation loss: 1.071.. Test accuracy: 0.705
# Epoch: 4/7.. Training loss: 1.667.. Validation loss: 1.020.. Test accuracy: 0.745
# Epoch: 4/7.. Training loss: 1.684.. Validation loss: 1.024.. Test accuracy: 0.714
# Epoch: 4/7.. Training loss: 1.711.. Validation loss: 0.997.. Test accuracy: 0.712
# Epoch: 4/7.. Training loss: 1.492.. Validation loss: 1.008.. Test accuracy: 0.726
# Epoch: 4/7.. Training loss: 1.434.. Validation loss: 1.041.. Test accuracy: 0.729
# Epoch: 4/7.. Training loss: 1.579.. Validation loss: 1.003.. Test accuracy: 0.735
# Epoch: 4/7.. Training loss: 1.450.. Validation loss: 0.953.. Test accuracy: 0.756
# Epoch: 4/7.. Training loss: 1.524.. Validation loss: 0.999.. Test accuracy: 0.713
# Epoch: 4/7.. Training loss: 1.399.. Validation loss: 1.016.. Test accuracy: 0.718
# Epoch: 4/7.. Training loss: 1.588.. Validation loss: 0.966.. Test accuracy: 0.737
# Epoch: 4/7.. Training loss: 1.671.. Validation loss: 0.963.. Test accuracy: 0.753
# Epoch: 4/7.. Training loss: 1.561.. Validation loss: 0.954.. Test accuracy: 0.740
# Epoch: 4/7.. Training loss: 1.610.. Validation loss: 0.986.. Test accuracy: 0.740
# Epoch: 4/7.. Training loss: 1.487.. Validation loss: 0.954.. Test accuracy: 0.752
# Epoch: 4/7.. Training loss: 1.635.. Validation loss: 0.912.. Test accuracy: 0.764
# Epoch: 4/7.. Training loss: 1.577.. Validation loss: 0.931.. Test accuracy: 0.760
# Epoch: 4/7.. Training loss: 1.536.. Validation loss: 0.949.. Test accuracy: 0.759
# Epoch: 4/7.. Training loss: 1.555.. Validation loss: 0.954.. Test accuracy: 0.743
# Epoch: 4/7.. Training loss: 1.549.. Validation loss: 0.934.. Test accuracy: 0.746
# Epoch: 4/7.. Training loss: 1.552.. Validation loss: 0.921.. Test accuracy: 0.756
# Epoch: 4/7.. Training loss: 1.518.. Validation loss: 0.918.. Test accuracy: 0.740
# Epoch: 4/7.. Training loss: 1.323.. Validation loss: 0.960.. Test accuracy: 0.738
# Epoch: 4/7.. Training loss: 1.492.. Validation loss: 0.919.. Test accuracy: 0.753
# Epoch: 4/7.. Training loss: 1.479.. Validation loss: 0.905.. Test accuracy: 0.768
# Epoch: 4/7.. Training loss: 1.501.. Validation loss: 0.855.. Test accuracy: 0.784
# Epoch: 4/7.. Training loss: 1.249.. Validation loss: 0.876.. Test accuracy: 0.752
# Epoch: 4/7.. Training loss: 1.362.. Validation loss: 0.894.. Test accuracy: 0.765
# Epoch: 4/7.. Training loss: 1.302.. Validation loss: 0.869.. Test accuracy: 0.764
# Epoch: 4/7.. Training loss: 1.429.. Validation loss: 0.915.. Test accuracy: 0.735
# Epoch: 4/7.. Training loss: 1.396.. Validation loss: 0.919.. Test accuracy: 0.770
# Epoch: 4/7.. Training loss: 1.403.. Validation loss: 0.883.. Test accuracy: 0.763
# Epoch: 4/7.. Training loss: 1.444.. Validation loss: 0.872.. Test accuracy: 0.762
# Epoch: 4/7.. Training loss: 1.373.. Validation loss: 0.874.. Test accuracy: 0.771
# Epoch: 4/7.. Training loss: 1.520.. Validation loss: 0.890.. Test accuracy: 0.751
# Epoch: 4/7.. Training loss: 1.404.. Validation loss: 0.834.. Test accuracy: 0.783
# Epoch: 4/7.. Training loss: 1.495.. Validation loss: 0.885.. Test accuracy: 0.758
# Epoch: 4/7.. Training loss: 1.163.. Validation loss: 0.850.. Test accuracy: 0.794
# Epoch: 4/7.. Training loss: 1.378.. Validation loss: 0.889.. Test accuracy: 0.759
# Epoch: 4/7.. Training loss: 1.304.. Validation loss: 0.893.. Test accuracy: 0.751
# Epoch: 4/7.. Training loss: 1.246.. Validation loss: 0.881.. Test accuracy: 0.755
# Epoch: 5/7.. Training loss: 1.525.. Validation loss: 0.843.. Test accuracy: 0.784
# Epoch: 5/7.. Training loss: 1.387.. Validation loss: 0.854.. Test accuracy: 0.757
# Epoch: 5/7.. Training loss: 1.619.. Validation loss: 0.869.. Test accuracy: 0.767
# Epoch: 5/7.. Training loss: 1.340.. Validation loss: 0.838.. Test accuracy: 0.774
# Epoch: 5/7.. Training loss: 1.220.. Validation loss: 0.841.. Test accuracy: 0.757
# Epoch: 5/7.. Training loss: 1.533.. Validation loss: 0.830.. Test accuracy: 0.782
# Epoch: 5/7.. Training loss: 1.288.. Validation loss: 0.872.. Test accuracy: 0.767
# Epoch: 5/7.. Training loss: 1.447.. Validation loss: 0.827.. Test accuracy: 0.776
# Epoch: 5/7.. Training loss: 1.507.. Validation loss: 0.851.. Test accuracy: 0.768
# Epoch: 5/7.. Training loss: 1.347.. Validation loss: 0.839.. Test accuracy: 0.780
# Epoch: 5/7.. Training loss: 1.372.. Validation loss: 0.810.. Test accuracy: 0.776
# Epoch: 5/7.. Training loss: 1.322.. Validation loss: 0.784.. Test accuracy: 0.780
# Epoch: 5/7.. Training loss: 1.287.. Validation loss: 0.846.. Test accuracy: 0.767
# Epoch: 5/7.. Training loss: 1.232.. Validation loss: 0.848.. Test accuracy: 0.761
# Epoch: 5/7.. Training loss: 1.260.. Validation loss: 0.815.. Test accuracy: 0.777
# Epoch: 5/7.. Training loss: 1.172.. Validation loss: 0.854.. Test accuracy: 0.758
# Epoch: 5/7.. Training loss: 1.384.. Validation loss: 0.789.. Test accuracy: 0.790
# Epoch: 5/7.. Training loss: 1.299.. Validation loss: 0.793.. Test accuracy: 0.800
# Epoch: 5/7.. Training loss: 1.355.. Validation loss: 0.790.. Test accuracy: 0.791
# Epoch: 5/7.. Training loss: 1.321.. Validation loss: 0.793.. Test accuracy: 0.780
# Epoch: 5/7.. Training loss: 1.469.. Validation loss: 0.801.. Test accuracy: 0.785
# Epoch: 5/7.. Training loss: 1.338.. Validation loss: 0.751.. Test accuracy: 0.819
# Epoch: 5/7.. Training loss: 1.195.. Validation loss: 0.754.. Test accuracy: 0.800
# Epoch: 5/7.. Training loss: 1.428.. Validation loss: 0.807.. Test accuracy: 0.784
# Epoch: 5/7.. Training loss: 1.350.. Validation loss: 0.801.. Test accuracy: 0.784
# Epoch: 5/7.. Training loss: 1.157.. Validation loss: 0.814.. Test accuracy: 0.780
# Epoch: 5/7.. Training loss: 1.299.. Validation loss: 0.774.. Test accuracy: 0.794
# Epoch: 5/7.. Training loss: 1.285.. Validation loss: 0.708.. Test accuracy: 0.818
# Epoch: 5/7.. Training loss: 1.439.. Validation loss: 0.742.. Test accuracy: 0.819
# Epoch: 5/7.. Training loss: 1.350.. Validation loss: 0.789.. Test accuracy: 0.806
# Epoch: 5/7.. Training loss: 1.115.. Validation loss: 0.830.. Test accuracy: 0.785
# Epoch: 5/7.. Training loss: 1.349.. Validation loss: 0.772.. Test accuracy: 0.788
# Epoch: 5/7.. Training loss: 1.096.. Validation loss: 0.730.. Test accuracy: 0.815
# Epoch: 5/7.. Training loss: 1.124.. Validation loss: 0.715.. Test accuracy: 0.821
# Epoch: 5/7.. Training loss: 1.121.. Validation loss: 0.757.. Test accuracy: 0.817
# Epoch: 5/7.. Training loss: 1.317.. Validation loss: 0.733.. Test accuracy: 0.819
# Epoch: 5/7.. Training loss: 1.363.. Validation loss: 0.790.. Test accuracy: 0.790
# Epoch: 5/7.. Training loss: 1.191.. Validation loss: 0.754.. Test accuracy: 0.808
# Epoch: 5/7.. Training loss: 1.105.. Validation loss: 0.776.. Test accuracy: 0.802
# Epoch: 5/7.. Training loss: 1.506.. Validation loss: 0.753.. Test accuracy: 0.800
# Epoch: 5/7.. Training loss: 1.169.. Validation loss: 0.831.. Test accuracy: 0.772
# Epoch: 6/7.. Training loss: 0.993.. Validation loss: 0.744.. Test accuracy: 0.800
# Epoch: 6/7.. Training loss: 1.072.. Validation loss: 0.751.. Test accuracy: 0.806
# Epoch: 6/7.. Training loss: 1.188.. Validation loss: 0.749.. Test accuracy: 0.786
# Epoch: 6/7.. Training loss: 1.319.. Validation loss: 0.792.. Test accuracy: 0.778
# Epoch: 6/7.. Training loss: 1.231.. Validation loss: 0.750.. Test accuracy: 0.803
# Epoch: 6/7.. Training loss: 1.267.. Validation loss: 0.739.. Test accuracy: 0.813
# Epoch: 6/7.. Training loss: 1.335.. Validation loss: 0.727.. Test accuracy: 0.818
# Epoch: 6/7.. Training loss: 1.177.. Validation loss: 0.773.. Test accuracy: 0.785
# Epoch: 6/7.. Training loss: 1.380.. Validation loss: 0.760.. Test accuracy: 0.787
# Epoch: 6/7.. Training loss: 1.171.. Validation loss: 0.697.. Test accuracy: 0.815
# Epoch: 6/7.. Training loss: 1.115.. Validation loss: 0.711.. Test accuracy: 0.816
# Epoch: 6/7.. Training loss: 1.206.. Validation loss: 0.732.. Test accuracy: 0.803
# Epoch: 6/7.. Training loss: 1.065.. Validation loss: 0.725.. Test accuracy: 0.797
# Epoch: 6/7.. Training loss: 1.234.. Validation loss: 0.681.. Test accuracy: 0.828
# Epoch: 6/7.. Training loss: 1.424.. Validation loss: 0.745.. Test accuracy: 0.797
# Epoch: 6/7.. Training loss: 1.061.. Validation loss: 0.688.. Test accuracy: 0.818
# Epoch: 6/7.. Training loss: 1.225.. Validation loss: 0.687.. Test accuracy: 0.817
# Epoch: 6/7.. Training loss: 1.146.. Validation loss: 0.664.. Test accuracy: 0.819
# Epoch: 6/7.. Training loss: 1.057.. Validation loss: 0.722.. Test accuracy: 0.794
# Epoch: 6/7.. Training loss: 1.148.. Validation loss: 0.698.. Test accuracy: 0.815
# Epoch: 6/7.. Training loss: 1.135.. Validation loss: 0.680.. Test accuracy: 0.814
# Epoch: 6/7.. Training loss: 1.128.. Validation loss: 0.692.. Test accuracy: 0.819
# Epoch: 6/7.. Training loss: 1.058.. Validation loss: 0.752.. Test accuracy: 0.785
# Epoch: 6/7.. Training loss: 1.270.. Validation loss: 0.717.. Test accuracy: 0.808
# Epoch: 6/7.. Training loss: 1.283.. Validation loss: 0.667.. Test accuracy: 0.826
# Epoch: 6/7.. Training loss: 1.256.. Validation loss: 0.680.. Test accuracy: 0.810
# Epoch: 6/7.. Training loss: 1.059.. Validation loss: 0.703.. Test accuracy: 0.804
# Epoch: 6/7.. Training loss: 1.082.. Validation loss: 0.707.. Test accuracy: 0.806
# Epoch: 6/7.. Training loss: 1.010.. Validation loss: 0.707.. Test accuracy: 0.795
# Epoch: 6/7.. Training loss: 1.099.. Validation loss: 0.659.. Test accuracy: 0.812
# Epoch: 6/7.. Training loss: 1.160.. Validation loss: 0.702.. Test accuracy: 0.818
# Epoch: 6/7.. Training loss: 1.140.. Validation loss: 0.739.. Test accuracy: 0.799
# Epoch: 6/7.. Training loss: 1.230.. Validation loss: 0.716.. Test accuracy: 0.815
# Epoch: 6/7.. Training loss: 1.269.. Validation loss: 0.698.. Test accuracy: 0.816
# Epoch: 6/7.. Training loss: 1.116.. Validation loss: 0.698.. Test accuracy: 0.806
# Epoch: 6/7.. Training loss: 1.179.. Validation loss: 0.688.. Test accuracy: 0.820
# Epoch: 6/7.. Training loss: 1.175.. Validation loss: 0.720.. Test accuracy: 0.807
# Epoch: 6/7.. Training loss: 1.301.. Validation loss: 0.705.. Test accuracy: 0.810
# Epoch: 6/7.. Training loss: 0.893.. Validation loss: 0.655.. Test accuracy: 0.833
# Epoch: 6/7.. Training loss: 1.121.. Validation loss: 0.697.. Test accuracy: 0.806
# Epoch: 6/7.. Training loss: 1.189.. Validation loss: 0.646.. Test accuracy: 0.827
# Epoch: 7/7.. Training loss: 1.075.. Validation loss: 0.630.. Test accuracy: 0.833
# Epoch: 7/7.. Training loss: 0.907.. Validation loss: 0.666.. Test accuracy: 0.806
# Epoch: 7/7.. Training loss: 1.064.. Validation loss: 0.681.. Test accuracy: 0.819
# Epoch: 7/7.. Training loss: 1.173.. Validation loss: 0.733.. Test accuracy: 0.789
# Epoch: 7/7.. Training loss: 1.094.. Validation loss: 0.659.. Test accuracy: 0.823
# Epoch: 7/7.. Training loss: 1.138.. Validation loss: 0.664.. Test accuracy: 0.815
# Epoch: 7/7.. Training loss: 1.078.. Validation loss: 0.666.. Test accuracy: 0.821
# Epoch: 7/7.. Training loss: 1.120.. Validation loss: 0.711.. Test accuracy: 0.807
# Epoch: 7/7.. Training loss: 0.999.. Validation loss: 0.672.. Test accuracy: 0.816
# Epoch: 7/7.. Training loss: 1.260.. Validation loss: 0.668.. Test accuracy: 0.824
# Epoch: 7/7.. Training loss: 1.056.. Validation loss: 0.687.. Test accuracy: 0.802
# Epoch: 7/7.. Training loss: 0.970.. Validation loss: 0.676.. Test accuracy: 0.818
# Epoch: 7/7.. Training loss: 1.221.. Validation loss: 0.670.. Test accuracy: 0.813
# Epoch: 7/7.. Training loss: 1.111.. Validation loss: 0.648.. Test accuracy: 0.825
# Epoch: 7/7.. Training loss: 1.241.. Validation loss: 0.643.. Test accuracy: 0.823
# Epoch: 7/7.. Training loss: 1.157.. Validation loss: 0.658.. Test accuracy: 0.817
# Epoch: 7/7.. Training loss: 1.225.. Validation loss: 0.651.. Test accuracy: 0.815
# Epoch: 7/7.. Training loss: 1.236.. Validation loss: 0.670.. Test accuracy: 0.825
# Epoch: 7/7.. Training loss: 1.065.. Validation loss: 0.660.. Test accuracy: 0.819
# Epoch: 7/7.. Training loss: 1.165.. Validation loss: 0.681.. Test accuracy: 0.826
# Epoch: 7/7.. Training loss: 1.270.. Validation loss: 0.674.. Test accuracy: 0.824
# Epoch: 7/7.. Training loss: 1.074.. Validation loss: 0.632.. Test accuracy: 0.835
# Epoch: 7/7.. Training loss: 0.989.. Validation loss: 0.663.. Test accuracy: 0.824
# Epoch: 7/7.. Training loss: 1.182.. Validation loss: 0.662.. Test accuracy: 0.839
# Epoch: 7/7.. Training loss: 1.165.. Validation loss: 0.635.. Test accuracy: 0.824
# Epoch: 7/7.. Training loss: 1.151.. Validation loss: 0.650.. Test accuracy: 0.824
# Epoch: 7/7.. Training loss: 1.091.. Validation loss: 0.648.. Test accuracy: 0.815
# Epoch: 7/7.. Training loss: 0.948.. Validation loss: 0.649.. Test accuracy: 0.830
# Epoch: 7/7.. Training loss: 1.008.. Validation loss: 0.635.. Test accuracy: 0.832
# Epoch: 7/7.. Training loss: 1.195.. Validation loss: 0.639.. Test accuracy: 0.827
# Epoch: 7/7.. Training loss: 1.095.. Validation loss: 0.629.. Test accuracy: 0.822
# Epoch: 7/7.. Training loss: 1.199.. Validation loss: 0.660.. Test accuracy: 0.823
# Epoch: 7/7.. Training loss: 1.067.. Validation loss: 0.621.. Test accuracy: 0.833
# Epoch: 7/7.. Training loss: 1.120.. Validation loss: 0.641.. Test accuracy: 0.834
# Epoch: 7/7.. Training loss: 1.030.. Validation loss: 0.622.. Test accuracy: 0.838
# Epoch: 7/7.. Training loss: 1.184.. Validation loss: 0.639.. Test accuracy: 0.820
# Epoch: 7/7.. Training loss: 1.024.. Validation loss: 0.606.. Test accuracy: 0.843
# Epoch: 7/7.. Training loss: 1.182.. Validation loss: 0.619.. Test accuracy: 0.829
# Epoch: 7/7.. Training loss: 0.947.. Validation loss: 0.628.. Test accuracy: 0.823
# Epoch: 7/7.. Training loss: 1.055.. Validation loss: 0.651.. Test accuracy: 0.817
# Epoch: 7/7.. Training loss: 1.240.. Validation loss: 0.665.. Test accuracy: 0.827

# %%
#changed graph to train_losses and testing_losses

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.plot(train_losses, label='Training loss')
plt.plot(validation_losses, label='Validation loss')
plt.legend(frameon=False)

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
test_loss = 0
accuracy = 0
model.to('cuda')


with torch.no_grad():
    for images, labels in testing_loader:
        images, labels = images.to('cuda'), labels.to('cuda')
        log_ps = model.forward(images) 
        batch_loss = criterion(log_ps, labels) 
        test_loss += batch_loss.item()             
        ps = torch.exp(log_ps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor))


print("Epoch: {}/{}..".format(e+1, epochs),
      "Test Loss: {:.3f}.. ".format(test_loss/len(testing_loader)),
      "Test Accuracy: {:.3f}".format(accuracy/len(testing_loader)))
# Out:
# Epoch: 7/7.. Test Loss: 0.848..  Test Accuracy: 0.763

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
model.class_to_idx = training_data.class_to_idx
checkpoint = {'input_size': input_size,
            'hidden_layer1': hidden_sizes[0],
            'hidden_layer2': hidden_sizes[1],
            'output_size': output_size,
            'epochs': epochs,
            'arch': 'alexnet',
            'classifier': classifier,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict(), 
            'class_to_idx': training_data.class_to_idx} 

torch.save(checkpoint, 'checkpoint.pth')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Sequential. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Linear. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ReLU. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Dropout. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LogSoftmax. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    model = getattr(torchvision.models, checkpoint['arch'])(pretrained=True)
    if checkpoint['arch'] == 'alexnet':
        model = models.alexnet(pretrained=True)
    else:
        print('alexnet is the only way')
    
    for param in model.parameters():
        param.requires_grad = False
    
    model.classifier = checkpoint['classifier']
    model.load_state_dict(checkpoint['state_dict'])
    model.class_to_index = checkpoint['class_to_idx']
    model.classifier.epochs = checkpoint['epochs']
        
    return model

model = load_checkpoint('checkpoint.pth') 
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=9216, out_features=1024, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (fc2): Linear(in_features=1024, out_features=256, bias=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (fc3): Linear(in_features=256, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
imgpath = test_dir + '/17/image_03830.jpg'

def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''

    transform = transforms.Compose([transforms.Resize(256),
                                    transforms.CenterCrop(224),
                                    transforms.ToTensor()
                                   ])
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
   

    load_data = Image.open(imgpath)
    load_data = transform(load_data).float()
    np_image = np.array(load_data)
    np_image = (np.ndarray.transpose(np_image, (1, 2, 0)) - mean)/std     
    np_image = np.ndarray.transpose(np_image, (2, 0, 1))               
    
    
    return np_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    image = image.transpose((1, 2, 0))
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax
    
imshow(process_image(imgpath))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):

    # TODO: Implement the code to predict the class from an image file
    #model.eval()
    model.to('cuda')
    
    img_torch = process_image(image_path)
    img_torch = torch.from_numpy(img_torch)
    
    img_torch = img_torch.unsqueeze_(0)
    img_torch = img_torch.float()
    
    with torch.no_grad():
        output = model.forward(img_torch.cuda()) 
        
    transform = F.softmax(output.data,dim=1) 

    return transform.topk(topk)

probs, classes = predict(imgpath, model)
print(probs)
print(classes)
# Out:
# tensor([[1.0000e+00, 2.5010e-07, 2.2901e-07, 1.8431e-07, 1.1073e-07]],
#        device='cuda:0')
# tensor([[11, 77, 94, 34, 65]], device='cuda:0')

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes


image = process_image(imgpath)

index = 17
plot = imshow(image, ax = plt)
plot.axis('off')
plot.title(cat_to_name[str(index)])
plot.show()

axes = predict(image, model)

yaxis = [cat_to_name[str(i)] for i in np.array(axes[1][0])]
y_pos = np.arange(len(yaxis))
xaxis = np.array(axes[0][0])   

plt.barh(y_pos, xaxis)
plt.xlabel('probability')
plt.yticks(y_pos, yaxis)
plt.title('probability of flower classification')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-925c6997b338> in <module>()
#      11 axes = predict(image, model)
#      12
# ---> 13 yaxis = [cat_to_name[str(i)] for i in np.array(axes[1][0])]
#      14 y_pos = np.arange(len(yaxis))
#      15 xaxis = np.array(axes[0][0])
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in __array__(self, dtype)
#     447     def __array__(self, dtype=None):
#     448         if dtype is None:
# --> 449             return self.numpy()
#     450         else:
#     451             return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert CUDA tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

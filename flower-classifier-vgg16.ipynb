# %% [markdown]
# <a href="https://colab.research.google.com/github/cassyay/flower-classifier/blob/master/flower-classifier-vgg16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
import json
import torchvision 
from torchvision import transforms, datasets
import torch 
from torch.utils.data import DataLoader
#from torch.optim import lr_scheduler
import torchvision.models as models
from collections import OrderedDict
from torch import nn, optim
import numpy as np
from PIL import Image
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
check_gpu = torch.cuda.is_available()

if not check_gpu:
    print('Running on CPU, switch to GPU if possible ...')
else:
    print('Training on GPU ...')
# Out:
# Training on GPU ...

# %%
#!unzip flower_data.zip
data_dir = 'flower_data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets

training_transform = transforms.Compose([
        transforms.RandomRotation(90),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
validation_transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
testing_transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])


# TODO: Load the datasets with ImageFolder
training_data = datasets.ImageFolder(train_dir, transform=training_transform)
validation_data = datasets.ImageFolder(valid_dir, transform=validation_transform)
testing_data = datasets.ImageFolder(test_dir, transform = testing_transform)

# TODO: Using the image datasets and the trainforms, define the dataloaders
training_loader = torch.utils.data.DataLoader(training_data, batch_size=32, shuffle=True) 
validation_loader = torch.utils.data.DataLoader(validation_data, batch_size = 32)
testing_loader = torch.utils.data.DataLoader(testing_data, batch_size = 32)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
model = models.vgg16(pretrained=True)

for param in model.parameters():
    param.requires_grad = False
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:14<00:00, 38.9MB/s]

# %%
#change 9216 
input_size = 25088
hidden_sizes = [1024, 256]
output_size = 102


model.classifier = nn.Sequential(OrderedDict([
                      ('fc1', nn.Linear(input_size, hidden_sizes[0])),
                      ('relu1', nn.ReLU()),
                      ('dropout1', nn.Dropout(p=0.1)),
                      ('fc2', nn.Linear(hidden_sizes[0], hidden_sizes[1])),
                      ('relu2', nn.ReLU()),
                      ('dropout2', nn.Dropout(p=0.1)),
                      ('fc3', nn.Linear(hidden_sizes[1], output_size)),
                      ('output', nn.LogSoftmax(dim=1))]))

classifier = model.classifier
criterion = nn.NLLLoss()
optimizer = optim.SGD(model.classifier.parameters(), lr=0.01)
#scheduler = lr_scheduler.StepLR(optimizer, step_size=6, gamma=0.1)

# %%
model.cuda()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=1024, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (fc2): Linear(in_features=1024, out_features=256, bias=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (fc3): Linear(in_features=256, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
epochs = 8
steps = 0
print_every = 5
train_losses, validation_losses = [], []
    
    
for e in range(epochs):
    running_loss = 0
    
    for images, labels in training_loader:
        steps += 1
        images, labels = images.to('cuda'), labels.to('cuda')
        
        optimizer.zero_grad()
                
        log_ps = model.forward(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
            

        if steps % print_every == 0:
            validation_loss = 0
            accuracy = 0
            model.eval()
                
            with torch.no_grad():
                for images, labels in validation_loader:
                    images, labels = images.to('cuda'), labels.to('cuda')
                    log_ps = model.forward(images)
                    batch_loss = criterion(log_ps, labels) 
                    validation_loss += batch_loss.item()   
                    ps = torch.exp(log_ps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor))
       
    
            train_losses.append(running_loss/len(training_loader)), 
            validation_losses.append(validation_loss/len(validation_loader))  

            print("Epoch: {}/{}..".format(e+1, epochs),
            "Training loss: {:.3f}..".format(running_loss/print_every),
            "Validation loss: {:.3f}..".format(validation_loss/len(validation_loader)),
            "Test accuracy: {:.3f}".format(accuracy/len(validation_loader)))
            running_loss = 0
            model.train()
# Out:
# Epoch: 1/8.. Training loss: 4.626.. Validation loss: 4.610.. Test accuracy: 0.017
# Epoch: 1/8.. Training loss: 4.609.. Validation loss: 4.584.. Test accuracy: 0.041
# Epoch: 1/8.. Training loss: 4.591.. Validation loss: 4.570.. Test accuracy: 0.053
# Epoch: 1/8.. Training loss: 4.581.. Validation loss: 4.552.. Test accuracy: 0.070
# Epoch: 1/8.. Training loss: 4.551.. Validation loss: 4.526.. Test accuracy: 0.060
# Epoch: 1/8.. Training loss: 4.547.. Validation loss: 4.501.. Test accuracy: 0.081
# Epoch: 1/8.. Training loss: 4.559.. Validation loss: 4.483.. Test accuracy: 0.059
# Epoch: 1/8.. Training loss: 4.497.. Validation loss: 4.453.. Test accuracy: 0.050
# Epoch: 1/8.. Training loss: 4.523.. Validation loss: 4.425.. Test accuracy: 0.093
# Epoch: 1/8.. Training loss: 4.465.. Validation loss: 4.394.. Test accuracy: 0.090
# Epoch: 1/8.. Training loss: 4.447.. Validation loss: 4.367.. Test accuracy: 0.083
# Epoch: 1/8.. Training loss: 4.441.. Validation loss: 4.341.. Test accuracy: 0.064
# Epoch: 1/8.. Training loss: 4.308.. Validation loss: 4.308.. Test accuracy: 0.046
# Epoch: 1/8.. Training loss: 4.356.. Validation loss: 4.284.. Test accuracy: 0.037
# Epoch: 1/8.. Training loss: 4.342.. Validation loss: 4.260.. Test accuracy: 0.072
# Epoch: 1/8.. Training loss: 4.370.. Validation loss: 4.219.. Test accuracy: 0.107
# Epoch: 1/8.. Training loss: 4.293.. Validation loss: 4.170.. Test accuracy: 0.125
# Epoch: 1/8.. Training loss: 4.237.. Validation loss: 4.135.. Test accuracy: 0.123
# Epoch: 1/8.. Training loss: 4.373.. Validation loss: 4.102.. Test accuracy: 0.153
# Epoch: 1/8.. Training loss: 4.301.. Validation loss: 4.084.. Test accuracy: 0.161
# Epoch: 1/8.. Training loss: 4.172.. Validation loss: 4.057.. Test accuracy: 0.137
# Epoch: 1/8.. Training loss: 4.182.. Validation loss: 4.005.. Test accuracy: 0.172
# Epoch: 1/8.. Training loss: 4.198.. Validation loss: 3.962.. Test accuracy: 0.168
# Epoch: 1/8.. Training loss: 4.096.. Validation loss: 3.925.. Test accuracy: 0.156
# Epoch: 1/8.. Training loss: 4.041.. Validation loss: 3.889.. Test accuracy: 0.148
# Epoch: 1/8.. Training loss: 4.025.. Validation loss: 3.826.. Test accuracy: 0.147
# Epoch: 1/8.. Training loss: 4.150.. Validation loss: 3.783.. Test accuracy: 0.192
# Epoch: 1/8.. Training loss: 3.926.. Validation loss: 3.734.. Test accuracy: 0.185
# Epoch: 1/8.. Training loss: 3.983.. Validation loss: 3.679.. Test accuracy: 0.198
# Epoch: 1/8.. Training loss: 3.876.. Validation loss: 3.644.. Test accuracy: 0.216
# Epoch: 1/8.. Training loss: 3.799.. Validation loss: 3.575.. Test accuracy: 0.203
# Epoch: 1/8.. Training loss: 3.747.. Validation loss: 3.536.. Test accuracy: 0.213
# Epoch: 1/8.. Training loss: 3.737.. Validation loss: 3.482.. Test accuracy: 0.220
# Epoch: 1/8.. Training loss: 3.779.. Validation loss: 3.435.. Test accuracy: 0.240
# Epoch: 1/8.. Training loss: 3.857.. Validation loss: 3.388.. Test accuracy: 0.255
# Epoch: 1/8.. Training loss: 3.730.. Validation loss: 3.329.. Test accuracy: 0.308
# Epoch: 1/8.. Training loss: 3.690.. Validation loss: 3.269.. Test accuracy: 0.306
# Epoch: 1/8.. Training loss: 3.591.. Validation loss: 3.216.. Test accuracy: 0.312
# Epoch: 1/8.. Training loss: 3.497.. Validation loss: 3.211.. Test accuracy: 0.255
# Epoch: 1/8.. Training loss: 3.524.. Validation loss: 3.094.. Test accuracy: 0.362
# Epoch: 1/8.. Training loss: 3.383.. Validation loss: 3.059.. Test accuracy: 0.347
# Epoch: 2/8.. Training loss: 3.546.. Validation loss: 3.007.. Test accuracy: 0.379
# Epoch: 2/8.. Training loss: 3.417.. Validation loss: 2.956.. Test accuracy: 0.389
# Epoch: 2/8.. Training loss: 3.363.. Validation loss: 2.927.. Test accuracy: 0.360
# Epoch: 2/8.. Training loss: 3.266.. Validation loss: 2.867.. Test accuracy: 0.362
# Epoch: 2/8.. Training loss: 3.327.. Validation loss: 2.830.. Test accuracy: 0.380
# Epoch: 2/8.. Training loss: 3.139.. Validation loss: 2.769.. Test accuracy: 0.436
# Epoch: 2/8.. Training loss: 3.338.. Validation loss: 2.751.. Test accuracy: 0.390
# Epoch: 2/8.. Training loss: 3.142.. Validation loss: 2.692.. Test accuracy: 0.413
# Epoch: 2/8.. Training loss: 3.126.. Validation loss: 2.673.. Test accuracy: 0.408
# Epoch: 2/8.. Training loss: 3.103.. Validation loss: 2.608.. Test accuracy: 0.428
# Epoch: 2/8.. Training loss: 3.011.. Validation loss: 2.559.. Test accuracy: 0.443
# Epoch: 2/8.. Training loss: 2.940.. Validation loss: 2.551.. Test accuracy: 0.429
# Epoch: 2/8.. Training loss: 3.155.. Validation loss: 2.464.. Test accuracy: 0.493
# Epoch: 2/8.. Training loss: 3.032.. Validation loss: 2.441.. Test accuracy: 0.470
# Epoch: 2/8.. Training loss: 2.757.. Validation loss: 2.407.. Test accuracy: 0.468
# Epoch: 2/8.. Training loss: 2.735.. Validation loss: 2.442.. Test accuracy: 0.431
# Epoch: 2/8.. Training loss: 2.708.. Validation loss: 2.393.. Test accuracy: 0.455
# Epoch: 2/8.. Training loss: 2.851.. Validation loss: 2.396.. Test accuracy: 0.458
# Epoch: 2/8.. Training loss: 2.695.. Validation loss: 2.280.. Test accuracy: 0.479
# Epoch: 2/8.. Training loss: 2.868.. Validation loss: 2.261.. Test accuracy: 0.485
# Epoch: 2/8.. Training loss: 2.579.. Validation loss: 2.208.. Test accuracy: 0.495
# Epoch: 2/8.. Training loss: 2.636.. Validation loss: 2.180.. Test accuracy: 0.497
# Epoch: 2/8.. Training loss: 2.454.. Validation loss: 2.105.. Test accuracy: 0.517
# Epoch: 2/8.. Training loss: 2.542.. Validation loss: 2.138.. Test accuracy: 0.515
# Epoch: 2/8.. Training loss: 2.613.. Validation loss: 2.067.. Test accuracy: 0.519
# Epoch: 2/8.. Training loss: 2.730.. Validation loss: 2.091.. Test accuracy: 0.487
# Epoch: 2/8.. Training loss: 2.733.. Validation loss: 1.980.. Test accuracy: 0.526
# Epoch: 2/8.. Training loss: 2.526.. Validation loss: 1.995.. Test accuracy: 0.540
# Epoch: 2/8.. Training loss: 2.444.. Validation loss: 1.968.. Test accuracy: 0.535
# Epoch: 2/8.. Training loss: 2.490.. Validation loss: 1.935.. Test accuracy: 0.530
# Epoch: 2/8.. Training loss: 2.532.. Validation loss: 1.957.. Test accuracy: 0.493
# Epoch: 2/8.. Training loss: 2.498.. Validation loss: 1.893.. Test accuracy: 0.551
# Epoch: 2/8.. Training loss: 2.379.. Validation loss: 1.842.. Test accuracy: 0.540
# Epoch: 2/8.. Training loss: 2.371.. Validation loss: 1.791.. Test accuracy: 0.558
# Epoch: 2/8.. Training loss: 2.407.. Validation loss: 1.777.. Test accuracy: 0.567
# Epoch: 2/8.. Training loss: 2.397.. Validation loss: 1.757.. Test accuracy: 0.592
# Epoch: 2/8.. Training loss: 2.397.. Validation loss: 1.721.. Test accuracy: 0.595
# Epoch: 2/8.. Training loss: 2.316.. Validation loss: 1.679.. Test accuracy: 0.612
# Epoch: 2/8.. Training loss: 2.206.. Validation loss: 1.657.. Test accuracy: 0.606
# Epoch: 2/8.. Training loss: 2.207.. Validation loss: 1.646.. Test accuracy: 0.593
# Epoch: 2/8.. Training loss: 2.439.. Validation loss: 1.611.. Test accuracy: 0.631
# Epoch: 3/8.. Training loss: 2.003.. Validation loss: 1.602.. Test accuracy: 0.610
# Epoch: 3/8.. Training loss: 1.942.. Validation loss: 1.607.. Test accuracy: 0.592
# Epoch: 3/8.. Training loss: 2.276.. Validation loss: 1.639.. Test accuracy: 0.603
# Epoch: 3/8.. Training loss: 2.109.. Validation loss: 1.574.. Test accuracy: 0.618
# Epoch: 3/8.. Training loss: 2.044.. Validation loss: 1.604.. Test accuracy: 0.601
# Epoch: 3/8.. Training loss: 2.177.. Validation loss: 1.514.. Test accuracy: 0.620
# Epoch: 3/8.. Training loss: 2.156.. Validation loss: 1.494.. Test accuracy: 0.638
# Epoch: 3/8.. Training loss: 2.132.. Validation loss: 1.679.. Test accuracy: 0.532
# Epoch: 3/8.. Training loss: 2.158.. Validation loss: 1.507.. Test accuracy: 0.621
# Epoch: 3/8.. Training loss: 2.053.. Validation loss: 1.441.. Test accuracy: 0.650
# Epoch: 3/8.. Training loss: 2.041.. Validation loss: 1.440.. Test accuracy: 0.639
# Epoch: 3/8.. Training loss: 1.935.. Validation loss: 1.390.. Test accuracy: 0.679
# Epoch: 3/8.. Training loss: 2.044.. Validation loss: 1.380.. Test accuracy: 0.673
# Epoch: 3/8.. Training loss: 2.121.. Validation loss: 1.397.. Test accuracy: 0.657
# Epoch: 3/8.. Training loss: 2.035.. Validation loss: 1.352.. Test accuracy: 0.697
# Epoch: 3/8.. Training loss: 1.927.. Validation loss: 1.382.. Test accuracy: 0.634
# Epoch: 3/8.. Training loss: 2.086.. Validation loss: 1.378.. Test accuracy: 0.641
# Epoch: 3/8.. Training loss: 2.063.. Validation loss: 1.340.. Test accuracy: 0.662
# Epoch: 3/8.. Training loss: 1.912.. Validation loss: 1.361.. Test accuracy: 0.638
# Epoch: 3/8.. Training loss: 1.777.. Validation loss: 1.366.. Test accuracy: 0.639
# Epoch: 3/8.. Training loss: 1.738.. Validation loss: 1.268.. Test accuracy: 0.685
# Epoch: 3/8.. Training loss: 1.979.. Validation loss: 1.248.. Test accuracy: 0.688
# Epoch: 3/8.. Training loss: 1.964.. Validation loss: 1.223.. Test accuracy: 0.692
# Epoch: 3/8.. Training loss: 1.949.. Validation loss: 1.247.. Test accuracy: 0.692
# Epoch: 3/8.. Training loss: 1.817.. Validation loss: 1.190.. Test accuracy: 0.683
# Epoch: 3/8.. Training loss: 1.917.. Validation loss: 1.196.. Test accuracy: 0.691
# Epoch: 3/8.. Training loss: 1.821.. Validation loss: 1.202.. Test accuracy: 0.694
# Epoch: 3/8.. Training loss: 1.861.. Validation loss: 1.210.. Test accuracy: 0.685
# Epoch: 3/8.. Training loss: 1.940.. Validation loss: 1.199.. Test accuracy: 0.708
# Epoch: 3/8.. Training loss: 1.935.. Validation loss: 1.137.. Test accuracy: 0.729
# Epoch: 3/8.. Training loss: 1.888.. Validation loss: 1.182.. Test accuracy: 0.692
# Epoch: 3/8.. Training loss: 1.821.. Validation loss: 1.118.. Test accuracy: 0.727
# Epoch: 3/8.. Training loss: 1.657.. Validation loss: 1.156.. Test accuracy: 0.697
# Epoch: 3/8.. Training loss: 1.639.. Validation loss: 1.100.. Test accuracy: 0.721
# Epoch: 3/8.. Training loss: 1.542.. Validation loss: 1.113.. Test accuracy: 0.719
# Epoch: 3/8.. Training loss: 1.669.. Validation loss: 1.118.. Test accuracy: 0.706
# Epoch: 3/8.. Training loss: 1.809.. Validation loss: 1.107.. Test accuracy: 0.711
# Epoch: 3/8.. Training loss: 1.632.. Validation loss: 1.097.. Test accuracy: 0.715
# Epoch: 3/8.. Training loss: 1.518.. Validation loss: 1.109.. Test accuracy: 0.704
# Epoch: 3/8.. Training loss: 1.774.. Validation loss: 1.114.. Test accuracy: 0.691
# Epoch: 3/8.. Training loss: 1.746.. Validation loss: 1.106.. Test accuracy: 0.694
# Epoch: 4/8.. Training loss: 1.720.. Validation loss: 1.056.. Test accuracy: 0.722
# Epoch: 4/8.. Training loss: 1.515.. Validation loss: 1.030.. Test accuracy: 0.728
# Epoch: 4/8.. Training loss: 1.670.. Validation loss: 1.079.. Test accuracy: 0.722
# Epoch: 4/8.. Training loss: 1.602.. Validation loss: 1.103.. Test accuracy: 0.712
# Epoch: 4/8.. Training loss: 1.576.. Validation loss: 1.046.. Test accuracy: 0.739
# Epoch: 4/8.. Training loss: 1.676.. Validation loss: 0.980.. Test accuracy: 0.754
# Epoch: 4/8.. Training loss: 1.557.. Validation loss: 1.020.. Test accuracy: 0.746
# Epoch: 4/8.. Training loss: 1.396.. Validation loss: 0.984.. Test accuracy: 0.738
# Epoch: 4/8.. Training loss: 1.767.. Validation loss: 1.003.. Test accuracy: 0.726
# Epoch: 4/8.. Training loss: 1.508.. Validation loss: 0.952.. Test accuracy: 0.751
# Epoch: 4/8.. Training loss: 1.467.. Validation loss: 0.977.. Test accuracy: 0.731
# Epoch: 4/8.. Training loss: 1.476.. Validation loss: 1.000.. Test accuracy: 0.716
# Epoch: 4/8.. Training loss: 1.563.. Validation loss: 0.979.. Test accuracy: 0.743
# Epoch: 4/8.. Training loss: 1.365.. Validation loss: 0.943.. Test accuracy: 0.764
# Epoch: 4/8.. Training loss: 1.807.. Validation loss: 0.942.. Test accuracy: 0.761
# Epoch: 4/8.. Training loss: 1.308.. Validation loss: 0.916.. Test accuracy: 0.771
# Epoch: 4/8.. Training loss: 1.555.. Validation loss: 0.943.. Test accuracy: 0.753
# Epoch: 4/8.. Training loss: 1.294.. Validation loss: 0.916.. Test accuracy: 0.761
# Epoch: 4/8.. Training loss: 1.357.. Validation loss: 0.980.. Test accuracy: 0.730
# Epoch: 4/8.. Training loss: 1.415.. Validation loss: 0.944.. Test accuracy: 0.731
# Epoch: 4/8.. Training loss: 1.465.. Validation loss: 0.958.. Test accuracy: 0.745
# Epoch: 4/8.. Training loss: 1.473.. Validation loss: 0.953.. Test accuracy: 0.749
# Epoch: 4/8.. Training loss: 1.617.. Validation loss: 0.929.. Test accuracy: 0.776
# Epoch: 4/8.. Training loss: 1.376.. Validation loss: 0.920.. Test accuracy: 0.753
# Epoch: 4/8.. Training loss: 1.406.. Validation loss: 0.862.. Test accuracy: 0.786
# Epoch: 4/8.. Training loss: 1.233.. Validation loss: 0.877.. Test accuracy: 0.768
# Epoch: 4/8.. Training loss: 1.516.. Validation loss: 0.927.. Test accuracy: 0.733
# Epoch: 4/8.. Training loss: 1.380.. Validation loss: 0.891.. Test accuracy: 0.769
# Epoch: 4/8.. Training loss: 1.512.. Validation loss: 0.855.. Test accuracy: 0.770
# Epoch: 4/8.. Training loss: 1.362.. Validation loss: 0.839.. Test accuracy: 0.778
# Epoch: 4/8.. Training loss: 1.502.. Validation loss: 0.860.. Test accuracy: 0.780
# Epoch: 4/8.. Training loss: 1.619.. Validation loss: 0.864.. Test accuracy: 0.788
# Epoch: 4/8.. Training loss: 1.416.. Validation loss: 0.922.. Test accuracy: 0.750
# Epoch: 4/8.. Training loss: 1.340.. Validation loss: 0.861.. Test accuracy: 0.778
# Epoch: 4/8.. Training loss: 1.557.. Validation loss: 0.836.. Test accuracy: 0.782
# Epoch: 4/8.. Training loss: 1.457.. Validation loss: 0.837.. Test accuracy: 0.782
# Epoch: 4/8.. Training loss: 1.360.. Validation loss: 0.824.. Test accuracy: 0.784
# Epoch: 4/8.. Training loss: 1.458.. Validation loss: 0.826.. Test accuracy: 0.767
# Epoch: 4/8.. Training loss: 1.266.. Validation loss: 0.801.. Test accuracy: 0.798
# Epoch: 4/8.. Training loss: 1.388.. Validation loss: 0.796.. Test accuracy: 0.800
# Epoch: 4/8.. Training loss: 1.393.. Validation loss: 0.804.. Test accuracy: 0.785
# Epoch: 5/8.. Training loss: 1.213.. Validation loss: 0.836.. Test accuracy: 0.772
# Epoch: 5/8.. Training loss: 1.281.. Validation loss: 0.778.. Test accuracy: 0.800
# Epoch: 5/8.. Training loss: 1.394.. Validation loss: 0.825.. Test accuracy: 0.777
# Epoch: 5/8.. Training loss: 1.389.. Validation loss: 0.798.. Test accuracy: 0.793
# Epoch: 5/8.. Training loss: 1.346.. Validation loss: 0.800.. Test accuracy: 0.789
# Epoch: 5/8.. Training loss: 1.328.. Validation loss: 0.807.. Test accuracy: 0.787
# Epoch: 5/8.. Training loss: 1.380.. Validation loss: 0.798.. Test accuracy: 0.788
# Epoch: 5/8.. Training loss: 1.298.. Validation loss: 0.781.. Test accuracy: 0.788
# Epoch: 5/8.. Training loss: 1.356.. Validation loss: 0.733.. Test accuracy: 0.828
# Epoch: 5/8.. Training loss: 1.259.. Validation loss: 0.741.. Test accuracy: 0.803
# Epoch: 5/8.. Training loss: 1.417.. Validation loss: 0.829.. Test accuracy: 0.779
# Epoch: 5/8.. Training loss: 1.344.. Validation loss: 0.764.. Test accuracy: 0.816
# Epoch: 5/8.. Training loss: 1.312.. Validation loss: 0.734.. Test accuracy: 0.804
# Epoch: 5/8.. Training loss: 1.381.. Validation loss: 0.751.. Test accuracy: 0.805
# Epoch: 5/8.. Training loss: 1.195.. Validation loss: 0.743.. Test accuracy: 0.816
# Epoch: 5/8.. Training loss: 1.141.. Validation loss: 0.737.. Test accuracy: 0.815
# Epoch: 5/8.. Training loss: 1.410.. Validation loss: 0.824.. Test accuracy: 0.773
# Epoch: 5/8.. Training loss: 1.192.. Validation loss: 0.774.. Test accuracy: 0.796
# Epoch: 5/8.. Training loss: 1.210.. Validation loss: 0.792.. Test accuracy: 0.779
# Epoch: 5/8.. Training loss: 1.229.. Validation loss: 0.776.. Test accuracy: 0.791
# Epoch: 5/8.. Training loss: 1.207.. Validation loss: 0.787.. Test accuracy: 0.779
# Epoch: 5/8.. Training loss: 1.165.. Validation loss: 0.749.. Test accuracy: 0.803
# Epoch: 5/8.. Training loss: 1.418.. Validation loss: 0.750.. Test accuracy: 0.817
# Epoch: 5/8.. Training loss: 1.103.. Validation loss: 0.747.. Test accuracy: 0.823
# Epoch: 5/8.. Training loss: 1.211.. Validation loss: 0.734.. Test accuracy: 0.812
# Epoch: 5/8.. Training loss: 1.308.. Validation loss: 0.707.. Test accuracy: 0.808
# Epoch: 5/8.. Training loss: 1.368.. Validation loss: 0.736.. Test accuracy: 0.813
# Epoch: 5/8.. Training loss: 1.179.. Validation loss: 0.756.. Test accuracy: 0.802
# Epoch: 5/8.. Training loss: 1.347.. Validation loss: 0.795.. Test accuracy: 0.782
# Epoch: 5/8.. Training loss: 1.236.. Validation loss: 0.761.. Test accuracy: 0.784
# Epoch: 5/8.. Training loss: 1.218.. Validation loss: 0.687.. Test accuracy: 0.830
# Epoch: 5/8.. Training loss: 1.385.. Validation loss: 0.704.. Test accuracy: 0.809
# Epoch: 5/8.. Training loss: 1.056.. Validation loss: 0.715.. Test accuracy: 0.810
# Epoch: 5/8.. Training loss: 1.129.. Validation loss: 0.744.. Test accuracy: 0.804
# Epoch: 5/8.. Training loss: 1.116.. Validation loss: 0.712.. Test accuracy: 0.812
# Epoch: 5/8.. Training loss: 1.187.. Validation loss: 0.713.. Test accuracy: 0.794
# Epoch: 5/8.. Training loss: 1.389.. Validation loss: 0.717.. Test accuracy: 0.804
# Epoch: 5/8.. Training loss: 1.290.. Validation loss: 0.712.. Test accuracy: 0.811
# Epoch: 5/8.. Training loss: 1.192.. Validation loss: 0.658.. Test accuracy: 0.818
# Epoch: 5/8.. Training loss: 1.209.. Validation loss: 0.640.. Test accuracy: 0.830
# Epoch: 5/8.. Training loss: 1.108.. Validation loss: 0.705.. Test accuracy: 0.799
# Epoch: 6/8.. Training loss: 1.061.. Validation loss: 0.693.. Test accuracy: 0.806
# Epoch: 6/8.. Training loss: 1.265.. Validation loss: 0.718.. Test accuracy: 0.809
# Epoch: 6/8.. Training loss: 1.034.. Validation loss: 0.679.. Test accuracy: 0.822
# Epoch: 6/8.. Training loss: 0.922.. Validation loss: 0.634.. Test accuracy: 0.835
# Epoch: 6/8.. Training loss: 1.219.. Validation loss: 0.675.. Test accuracy: 0.825
# Epoch: 6/8.. Training loss: 1.209.. Validation loss: 0.646.. Test accuracy: 0.834
# Epoch: 6/8.. Training loss: 1.113.. Validation loss: 0.647.. Test accuracy: 0.831
# Epoch: 6/8.. Training loss: 1.291.. Validation loss: 0.630.. Test accuracy: 0.836
# Epoch: 6/8.. Training loss: 0.904.. Validation loss: 0.635.. Test accuracy: 0.826
# Epoch: 6/8.. Training loss: 1.159.. Validation loss: 0.631.. Test accuracy: 0.833
# Epoch: 6/8.. Training loss: 1.047.. Validation loss: 0.656.. Test accuracy: 0.830
# Epoch: 6/8.. Training loss: 1.061.. Validation loss: 0.637.. Test accuracy: 0.842
# Epoch: 6/8.. Training loss: 1.034.. Validation loss: 0.653.. Test accuracy: 0.825
# Epoch: 6/8.. Training loss: 1.159.. Validation loss: 0.678.. Test accuracy: 0.811
# Epoch: 6/8.. Training loss: 1.187.. Validation loss: 0.649.. Test accuracy: 0.819
# Epoch: 6/8.. Training loss: 1.000.. Validation loss: 0.648.. Test accuracy: 0.819
# Epoch: 6/8.. Training loss: 1.041.. Validation loss: 0.670.. Test accuracy: 0.815
# Epoch: 6/8.. Training loss: 0.993.. Validation loss: 0.635.. Test accuracy: 0.821
# Epoch: 6/8.. Training loss: 0.908.. Validation loss: 0.713.. Test accuracy: 0.806
# Epoch: 6/8.. Training loss: 1.070.. Validation loss: 0.697.. Test accuracy: 0.815
# Epoch: 6/8.. Training loss: 1.129.. Validation loss: 0.629.. Test accuracy: 0.834
# Epoch: 6/8.. Training loss: 1.293.. Validation loss: 0.626.. Test accuracy: 0.833
# Epoch: 6/8.. Training loss: 1.185.. Validation loss: 0.617.. Test accuracy: 0.825
# Epoch: 6/8.. Training loss: 1.134.. Validation loss: 0.637.. Test accuracy: 0.827
# Epoch: 6/8.. Training loss: 1.011.. Validation loss: 0.655.. Test accuracy: 0.818
# Epoch: 6/8.. Training loss: 1.002.. Validation loss: 0.651.. Test accuracy: 0.826
# Epoch: 6/8.. Training loss: 1.116.. Validation loss: 0.612.. Test accuracy: 0.836
# Epoch: 6/8.. Training loss: 1.034.. Validation loss: 0.603.. Test accuracy: 0.841
# Epoch: 6/8.. Training loss: 1.102.. Validation loss: 0.642.. Test accuracy: 0.811
# Epoch: 6/8.. Training loss: 1.016.. Validation loss: 0.627.. Test accuracy: 0.823
# Epoch: 6/8.. Training loss: 1.176.. Validation loss: 0.646.. Test accuracy: 0.824
# Epoch: 6/8.. Training loss: 0.964.. Validation loss: 0.616.. Test accuracy: 0.833
# Epoch: 6/8.. Training loss: 1.164.. Validation loss: 0.657.. Test accuracy: 0.812
# Epoch: 6/8.. Training loss: 1.089.. Validation loss: 0.603.. Test accuracy: 0.844
# Epoch: 6/8.. Training loss: 1.151.. Validation loss: 0.612.. Test accuracy: 0.843
# Epoch: 6/8.. Training loss: 1.089.. Validation loss: 0.594.. Test accuracy: 0.848
# Epoch: 6/8.. Training loss: 0.959.. Validation loss: 0.613.. Test accuracy: 0.840
# Epoch: 6/8.. Training loss: 1.069.. Validation loss: 0.594.. Test accuracy: 0.846
# Epoch: 6/8.. Training loss: 1.415.. Validation loss: 0.641.. Test accuracy: 0.827
# Epoch: 6/8.. Training loss: 0.994.. Validation loss: 0.632.. Test accuracy: 0.831
# Epoch: 6/8.. Training loss: 1.188.. Validation loss: 0.586.. Test accuracy: 0.839
# Epoch: 7/8.. Training loss: 1.139.. Validation loss: 0.580.. Test accuracy: 0.852
# Epoch: 7/8.. Training loss: 1.169.. Validation loss: 0.585.. Test accuracy: 0.845
# Epoch: 7/8.. Training loss: 1.184.. Validation loss: 0.585.. Test accuracy: 0.852
# Epoch: 7/8.. Training loss: 1.016.. Validation loss: 0.595.. Test accuracy: 0.840
# Epoch: 7/8.. Training loss: 0.882.. Validation loss: 0.576.. Test accuracy: 0.841
# Epoch: 7/8.. Training loss: 1.039.. Validation loss: 0.590.. Test accuracy: 0.842
# Epoch: 7/8.. Training loss: 1.201.. Validation loss: 0.610.. Test accuracy: 0.842
# Epoch: 7/8.. Training loss: 1.139.. Validation loss: 0.552.. Test accuracy: 0.857
# Epoch: 7/8.. Training loss: 1.061.. Validation loss: 0.569.. Test accuracy: 0.854
# Epoch: 7/8.. Training loss: 0.969.. Validation loss: 0.549.. Test accuracy: 0.850
# Epoch: 7/8.. Training loss: 0.862.. Validation loss: 0.556.. Test accuracy: 0.855
# Epoch: 7/8.. Training loss: 0.974.. Validation loss: 0.559.. Test accuracy: 0.853
# Epoch: 7/8.. Training loss: 0.964.. Validation loss: 0.547.. Test accuracy: 0.840
# Epoch: 7/8.. Training loss: 1.003.. Validation loss: 0.556.. Test accuracy: 0.856
# Epoch: 7/8.. Training loss: 1.132.. Validation loss: 0.566.. Test accuracy: 0.857
# Epoch: 7/8.. Training loss: 0.924.. Validation loss: 0.531.. Test accuracy: 0.858
# Epoch: 7/8.. Training loss: 0.866.. Validation loss: 0.567.. Test accuracy: 0.853
# Epoch: 7/8.. Training loss: 1.081.. Validation loss: 0.565.. Test accuracy: 0.847
# Epoch: 7/8.. Training loss: 0.971.. Validation loss: 0.537.. Test accuracy: 0.856
# Epoch: 7/8.. Training loss: 1.007.. Validation loss: 0.550.. Test accuracy: 0.851
# Epoch: 7/8.. Training loss: 0.777.. Validation loss: 0.568.. Test accuracy: 0.838
# Epoch: 7/8.. Training loss: 0.996.. Validation loss: 0.563.. Test accuracy: 0.847
# Epoch: 7/8.. Training loss: 0.770.. Validation loss: 0.540.. Test accuracy: 0.854
# Epoch: 7/8.. Training loss: 1.030.. Validation loss: 0.522.. Test accuracy: 0.868
# Epoch: 7/8.. Training loss: 1.137.. Validation loss: 0.565.. Test accuracy: 0.841
# Epoch: 7/8.. Training loss: 0.973.. Validation loss: 0.575.. Test accuracy: 0.838
# Epoch: 7/8.. Training loss: 1.193.. Validation loss: 0.547.. Test accuracy: 0.867
# Epoch: 7/8.. Training loss: 0.904.. Validation loss: 0.536.. Test accuracy: 0.859
# Epoch: 7/8.. Training loss: 0.938.. Validation loss: 0.561.. Test accuracy: 0.858
# Epoch: 7/8.. Training loss: 0.956.. Validation loss: 0.600.. Test accuracy: 0.834
# Epoch: 7/8.. Training loss: 0.965.. Validation loss: 0.559.. Test accuracy: 0.845
# Epoch: 7/8.. Training loss: 1.156.. Validation loss: 0.543.. Test accuracy: 0.858
# Epoch: 7/8.. Training loss: 1.109.. Validation loss: 0.552.. Test accuracy: 0.851
# Epoch: 7/8.. Training loss: 1.082.. Validation loss: 0.584.. Test accuracy: 0.833
# Epoch: 7/8.. Training loss: 1.137.. Validation loss: 0.556.. Test accuracy: 0.842
# Epoch: 7/8.. Training loss: 0.935.. Validation loss: 0.572.. Test accuracy: 0.840
# Epoch: 7/8.. Training loss: 1.010.. Validation loss: 0.572.. Test accuracy: 0.840
# Epoch: 7/8.. Training loss: 1.002.. Validation loss: 0.549.. Test accuracy: 0.843
# Epoch: 7/8.. Training loss: 1.006.. Validation loss: 0.568.. Test accuracy: 0.843
# Epoch: 7/8.. Training loss: 1.135.. Validation loss: 0.555.. Test accuracy: 0.846
# Epoch: 7/8.. Training loss: 0.918.. Validation loss: 0.548.. Test accuracy: 0.849
# Epoch: 8/8.. Training loss: 1.090.. Validation loss: 0.550.. Test accuracy: 0.852
# Epoch: 8/8.. Training loss: 0.944.. Validation loss: 0.531.. Test accuracy: 0.847
# Epoch: 8/8.. Training loss: 0.997.. Validation loss: 0.522.. Test accuracy: 0.855
# Epoch: 8/8.. Training loss: 0.941.. Validation loss: 0.548.. Test accuracy: 0.855
# Epoch: 8/8.. Training loss: 1.072.. Validation loss: 0.531.. Test accuracy: 0.847
# Epoch: 8/8.. Training loss: 1.070.. Validation loss: 0.550.. Test accuracy: 0.848
# Epoch: 8/8.. Training loss: 1.032.. Validation loss: 0.546.. Test accuracy: 0.856
# Epoch: 8/8.. Training loss: 0.977.. Validation loss: 0.528.. Test accuracy: 0.872
# Epoch: 8/8.. Training loss: 1.071.. Validation loss: 0.526.. Test accuracy: 0.855
# Epoch: 8/8.. Training loss: 0.831.. Validation loss: 0.514.. Test accuracy: 0.854
# Epoch: 8/8.. Training loss: 0.760.. Validation loss: 0.526.. Test accuracy: 0.865
# Epoch: 8/8.. Training loss: 0.789.. Validation loss: 0.567.. Test accuracy: 0.847
# Epoch: 8/8.. Training loss: 0.944.. Validation loss: 0.524.. Test accuracy: 0.868
# Epoch: 8/8.. Training loss: 1.039.. Validation loss: 0.524.. Test accuracy: 0.865
# Epoch: 8/8.. Training loss: 0.890.. Validation loss: 0.519.. Test accuracy: 0.858
# Epoch: 8/8.. Training loss: 1.116.. Validation loss: 0.513.. Test accuracy: 0.864
# Epoch: 8/8.. Training loss: 0.798.. Validation loss: 0.537.. Test accuracy: 0.857
# Epoch: 8/8.. Training loss: 0.782.. Validation loss: 0.518.. Test accuracy: 0.863
# Epoch: 8/8.. Training loss: 0.909.. Validation loss: 0.499.. Test accuracy: 0.872
# Epoch: 8/8.. Training loss: 1.019.. Validation loss: 0.556.. Test accuracy: 0.844
# Epoch: 8/8.. Training loss: 0.903.. Validation loss: 0.489.. Test accuracy: 0.872
# Epoch: 8/8.. Training loss: 0.760.. Validation loss: 0.506.. Test accuracy: 0.865
# Epoch: 8/8.. Training loss: 1.046.. Validation loss: 0.516.. Test accuracy: 0.865
# Epoch: 8/8.. Training loss: 1.063.. Validation loss: 0.523.. Test accuracy: 0.857
# Epoch: 8/8.. Training loss: 0.814.. Validation loss: 0.517.. Test accuracy: 0.858
# Epoch: 8/8.. Training loss: 0.938.. Validation loss: 0.494.. Test accuracy: 0.867
# Epoch: 8/8.. Training loss: 0.837.. Validation loss: 0.508.. Test accuracy: 0.867
# Epoch: 8/8.. Training loss: 0.973.. Validation loss: 0.475.. Test accuracy: 0.871
# Epoch: 8/8.. Training loss: 0.731.. Validation loss: 0.504.. Test accuracy: 0.870
# Epoch: 8/8.. Training loss: 0.804.. Validation loss: 0.481.. Test accuracy: 0.867
# Epoch: 8/8.. Training loss: 0.836.. Validation loss: 0.481.. Test accuracy: 0.872
# Epoch: 8/8.. Training loss: 0.832.. Validation loss: 0.499.. Test accuracy: 0.866
# Epoch: 8/8.. Training loss: 0.977.. Validation loss: 0.485.. Test accuracy: 0.870
# Epoch: 8/8.. Training loss: 0.961.. Validation loss: 0.474.. Test accuracy: 0.878
# Epoch: 8/8.. Training loss: 0.969.. Validation loss: 0.481.. Test accuracy: 0.878
# Epoch: 8/8.. Training loss: 0.996.. Validation loss: 0.458.. Test accuracy: 0.883
# Epoch: 8/8.. Training loss: 0.881.. Validation loss: 0.478.. Test accuracy: 0.880
# Epoch: 8/8.. Training loss: 0.908.. Validation loss: 0.524.. Test accuracy: 0.863
# Epoch: 8/8.. Training loss: 0.965.. Validation loss: 0.486.. Test accuracy: 0.860
# Epoch: 8/8.. Training loss: 0.904.. Validation loss: 0.494.. Test accuracy: 0.864
# Epoch: 8/8.. Training loss: 0.704.. Validation loss: 0.512.. Test accuracy: 0.863

# %%
#changed graph to train_losses and testing_losses

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.plot(train_losses, label='Training loss')
plt.plot(validation_losses, label='Validation loss')
plt.legend(frameon=False)

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
test_loss = 0
accuracy = 0
model.to('cuda')


with torch.no_grad():
    for images, labels in testing_loader:
        images, labels = images.to('cuda'), labels.to('cuda')
        log_ps = model.forward(images) 
        batch_loss = criterion(log_ps, labels) 
        test_loss += batch_loss.item()             
        ps = torch.exp(log_ps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor))


print("Total epochs: {}..".format(epochs), "\nAccuracy on test images: {:.3f}".format(accuracy/len(testing_loader)))
# Out:
# Total epochs: 8..
# Accuracy on test images: 0.817

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
model.class_to_idx = training_data.class_to_idx
checkpoint = {'input_size': input_size,
            'hidden_layer1': hidden_sizes[0],
            'hidden_layer2': hidden_sizes[1],
            'output_size': output_size,
            'epochs': epochs,
            'arch': 'vgg16',
            'classifier': classifier,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict(), 
            'class_to_idx': training_data.class_to_idx} 

torch.save(checkpoint, 'checkpoint.pth')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Sequential. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Linear. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ReLU. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Dropout. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LogSoftmax. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    model = getattr(torchvision.models, checkpoint['arch'])(pretrained=True)
    if checkpoint['arch'] == 'vgg16':
        model = models.vgg16(pretrained=True)
    else:
        print('vgg16 is the only way')
    
    for param in model.parameters():
        param.requires_grad = False
    
    model.classifier = checkpoint['classifier']
    model.load_state_dict(checkpoint['state_dict'])
    model.class_to_index = checkpoint['class_to_idx']
    model.classifier.epochs = checkpoint['epochs']
        
    return model

model = load_checkpoint('checkpoint.pth') 
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=1024, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (fc2): Linear(in_features=1024, out_features=256, bias=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (fc3): Linear(in_features=256, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
''' Scales, crops, and normalizes a PIL image for a PyTorch model, returns an Numpy array'''

def process_image(image):
  transform = transforms.Compose([transforms.Resize(256),
                                    transforms.CenterCrop(224),
                                    transforms.ToTensor()
                                   ])
  mean = np.array([0.485, 0.456, 0.406])
  std = np.array([0.229, 0.224, 0.225])
   

  load_data = Image.open(image)
  load_data = transform(load_data).float()
  np_image = np.array(load_data)
  np_image = (np.ndarray.transpose(np_image, (1, 2, 0)) - mean)/std     
  np_image = np.ndarray.transpose(np_image, (2, 0, 1))               
    
    
  return np_image

img = test_dir + '/17/image_03830.jpg'
img = process_image(img)
print(img.shape)
# Out:
# (3, 224, 224)

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
      
    image = image.transpose((1, 2, 0))
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

imgpath = test_dir + '/17/image_03830.jpg'
imshow(process_image(imgpath))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):

    # TODO: Implement the code to predict the class from an image file
    #model.eval()
    model.to('cuda')
    
    img_torch = process_image(image_path)
    img_torch = torch.from_numpy(img_torch)
    
    img_torch = img_torch.unsqueeze_(0)
    img_torch = img_torch.float()
    
    with torch.no_grad():
        output = model.forward(img_torch.cuda()) 
        
    transform = F.softmax(output.data,dim=1) 

    return transform.topk(topk)

probs, classes = predict(imgpath, model)
print(probs)
print(classes)
# Out:
# tensor([[0.9528, 0.0234, 0.0157, 0.0046, 0.0012]], device='cuda:0')
# tensor([[11, 30, 77, 65, 34]], device='cuda:0')

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
def sanity_check(path):

  index = int(path.split('/')[1])
  imagepath = test_dir + path
  image = process_image(imagepath)

  plot = imshow(image, ax = plt)
  plot.axis('off')
  plot.title(cat_to_name[str(index)])
  plot.show()

  axes = predict(imagepath, model)

  yaxis = [cat_to_name[str(i)] for i in np.array(axes[1][0].cpu())]
  y_pos = np.arange(len(yaxis))
  xaxis = np.array(axes[0][0].cpu().numpy())   

  plt.barh(y_pos, xaxis)
  plt.xlabel('probability')
  plt.yticks(y_pos, yaxis)
  plt.title('probability of flower classification')

  plt.show()

# %%
sanity_check('/40/image_04563.jpg')

# %%
sanity_check('/61/image_06248.jpg')

# %%
sanity_check('/84/image_02557.jpg')

# %%
sanity_check('/73/image_00349.jpg')
